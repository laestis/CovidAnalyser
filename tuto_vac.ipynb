# %%
#import class
import vacdata
#initialize vac object
vac=vacdata.vacdata()
#prepare datas
vac.clean()
vac.doses_by_day()

# %%
#plot vac by date
vac.plot_doses_by_date('France')

# %%
#Truncate absurd values
vac.truncate('France',1000000)
vac.plot_doses_by_date('France')

# %%
#plot vac by days since beginning of vaccination campaign
vac.plot_doses_by_day('France')

# %%
#plot purcentage of vaccinated population
vac.plot_per_hundred_by_date('France')
